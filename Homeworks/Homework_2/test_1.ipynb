# %%
import pandas as pd
import numpy as np
import requests

# %%
list_homes = []
total_ = 1
offset_ = 0
limit_ = 1000


while offset_ <= total_:
    url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?'\
          f'offset={offset_}&limit={limit_}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
    offset_ += limit_
    res = requests.get(url)
    objects_data = res.json()
    total_ = objects_data['data']['total']
    list_homes.extend(objects_data['data']['list'])
    print(f'уже загружено {len(list_homes)} объектов из {total_}')
# Out:
# уже загружено 1000 объектов из 11659
# уже загружено 2000 объектов из 11659
# уже загружено 3000 объектов из 11659
# уже загружено 4000 объектов из 11659
# уже загружено 5000 объектов из 11659
# уже загружено 6000 объектов из 11659
# уже загружено 7000 объектов из 11659
# уже загружено 8000 объектов из 11659
# уже загружено 9000 объектов из 11659
# уже загружено 10000 объектов из 11659
# уже загружено 11000 объектов из 11659
# уже загружено 11659 объектов из 11659

# %%
print(len(list_homes))
# Out:
# 11659

# %%
df = pd.json_normalize(list_homes)

# %%
df.head()
# Out:
#    hobjId  objId  rpdRegionCd                          objAddr  objFloorMin  \
# 0   34754  13399           72  г Тюмень, ул Профсоюзная, д. 56            1
# 1   37219  13391           72  г Тюмень, ул Профсоюзная, д. 56            3
# 2   39024  13383           72  г Тюмень, ул Профсоюзная, д. 56            4
# 3   37165  13398           72  г Тюмень, ул Профсоюзная, д. 56            7
# 4   37201  13397           72  г Тюмень, ул Профсоюзная, д. 56            6
#
#    objFloorMax  objElemLivingCnt objReady100PercDt  objSquareLiving  \
# 0            1                 0        2024-12-31             0.00
# 1           12                44        2023-12-31          4343.90
# 2           20                68        2023-12-31          6423.85
# 3           10                43        2024-12-31          4812.98
# 4           12                65        2024-12-31          6251.10
#
#    objCompensFundFlg  ...  developer.orgForm.fullForm  \
# ...

# %%
df.shape
# Out:
# (11659, 39)

# %%
# Сохраняем в csv файл
df.to_csv('vacancies.csv', index=False)
# Сохраняем в эксель-файл
df.to_excel('vacancies.xlsx', index=False)
# Сохраняем в файл в формате pickle
df.to_pickle('vacancies.pkl')
